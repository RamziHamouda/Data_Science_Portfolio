# %%
import datetime
import warnings
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import xgboost
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %matplotlib inline
sns.set(style="darkgrid")
pd.set_option('display.float_format', lambda x: '%.2f' % x)
warnings.filterwarnings("ignore")

from pandas.testing import assert_frame_equal

import lightgbm as lgb
from lightgbm import LGBMRegressor

from math import isnan



from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
train = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Infor\training_set.csv')
test = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Infor\testing_set.csv')
submission = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Infor\submission_sample.csv')

# %%
capacities = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Infor\hotels_capacities.csv')
capacities
# Out:
#   Hotel;Capacity
# 0           1;23
# 1          2;251
# 2          3;123
# 3           4;51

# %%
capacities['Hotel_id'] = capacities['Hotel;Capacity'].str.split(';').map(lambda x: x[0].strip())
capacities['Capacity'] = capacities['Hotel;Capacity'].str.split(';').map(lambda x: x[1].strip())
capacities = capacities.drop('Hotel;Capacity', axis=1)
capacities
# Out:
#   Hotel_id Capacity
# 0        1       23
# 1        2      251
# 2        3      123
# 3        4       51

# %%
print('\n******* train ********\n', 'shape: ', train.shape, '\n', train.columns, '\n',\
      train.describe(), '\n', train.isnull().sum() )

print('\n******* test ********\n', 'shape: ', test.shape, '\n', test.columns, '\n', \
      test.describe(), '\n', test.isnull().sum() )

print('\n******* submission ********\n', 'shape: ', submission.shape, '\n', submission.columns, '\n', \
      submission.describe(), '\n', submission.isnull().sum() )
# Out:
# ******* train ********
#  shape:  (356720, 37)
#  Index(['Row_id', 'Hotel_id', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
#        'HotelPrice_0', 'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0',
#        'PriceComp4_0', 'BKG_1', 'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14',
#        'Revenue_14', 'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14',
#        'PriceComp3_14', 'PriceComp4_14', 'BKG_21', 'Revenue_21',
#        'HotelPrice_21', 'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21',
#        'PriceComp4_21', 'BKG_28', 'Revenue_28', 'HotelPrice_28',
#        'PriceComp1_28', 'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'],
#       dtype='object')
#            Row_id  Hotel_id   Date_id        LT     BKG_0  Revenue_0  \
# count  356720.00 356720.00 356720.00 356720.00 356720.00  356720.00
# mean  2783126.14      2.60  43380.50    184.44      7.64     633.84
# std   1212997.91      1.11    145.13    104.71     18.98    1670.80
# min   1000001.00      1.00  43060.00      0.00      0.00       0.00
# 25%   2089180.75      2.00  43275.00     95.00      0.00       0.00
# 50%   3178360.50      3.00  43379.00    185.00      0.01       2.15
# 75%   4267540.25      4.00  43485.00    275.00      6.00     522.00
# max   4356720.00      4.00  43736.00    365.00    243.00   28727.17
#
#        HotelPrice_0  PriceComp1_0  PriceComp2_0  PriceComp3_0      ...        \
# count     356720.00     356720.00     356720.00     356720.00      ...
# mean          99.58         85.93        121.81        112.45      ...
# std           74.74         61.34         65.43         68.25      ...
# min            0.00          0.00          0.00          0.00      ...
# 25%           59.00         53.99         99.00         59.99      ...
# 50%           80.00         62.99        109.99         89.99      ...
# 75%          149.99        119.99        149.14        182.00      ...
# max          474.51        510.10        330.56        357.00      ...
#
#        PriceComp2_21  PriceComp3_21  PriceComp4_21    BKG_28  Revenue_28  \
# count      356720.00      356720.00      356720.00 356720.00   356720.00
# mean          107.88         100.66          97.04      4.58      395.96
# std            72.80          73.69          83.65     12.00     1146.64
# min            -1.00          -1.00          -1.00     -1.00       -1.00
# 25%            85.00          59.99           0.00      0.00        0.00
# 50%           105.00          84.99          94.00      0.00        0.00
# 75%           139.99         177.00         151.20      3.00      281.39
# max           303.28         357.00         999.00    217.00    27764.93
#
#        HotelPrice_28  PriceComp1_28  PriceComp2_28  PriceComp3_28  \
# count      356720.00      356720.00      356720.00      356720.00
# mean           85.60          72.83         103.24          96.82
# std            78.75          64.07          74.43          74.99
# min            -1.00          -1.00          -1.00          -1.00
# 25%             0.00           0.00          11.20          15.55
# 50%            75.00          59.99         104.99          82.00
# 75%           139.00         107.17         139.99         177.00
# max           329.99         462.43         301.97         347.00
#
#        PriceComp4_28
# count      356720.00
# mean           93.31
# std            84.16
# min            -1.00
# 25%             0.00
# 50%            89.99
# 75%           151.20
# max           999.00
#
# [8 rows x 36 columns]
#  Row_id           0
# Hotel_id         0
# Date_id          0
# Date             0
# LT               0
# BKG_0            0
# Revenue_0        0
# HotelPrice_0     0
# PriceComp1_0     0
# PriceComp2_0     0
# PriceComp3_0     0
# PriceComp4_0     0
# BKG_1            0
# Revenue_1        0
# BKG_7            0
# Revenue_7        0
# BKG_14           0
# Revenue_14       0
# HotelPrice_14    0
# PriceComp1_14    0
# PriceComp2_14    0
# PriceComp3_14    0
# PriceComp4_14    0
# BKG_21           0
# Revenue_21       0
# HotelPrice_21    0
# PriceComp1_21    0
# PriceComp2_21    0
# PriceComp3_21    0
# PriceComp4_21    0
# BKG_28           0
# Revenue_28       0
# HotelPrice_28    0
# PriceComp1_28    0
# PriceComp2_28    0
# PriceComp3_28    0
# PriceComp4_28    0
# dtype: int64
#
# ******* test ********
#  shape:  (152882, 36)
#  Index(['Row_id', 'Hotel_id', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
#        'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0', 'PriceComp4_0', 'BKG_1',
#        'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
#        'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
#        'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
#        'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
#        'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
#        'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'],
#       dtype='object')
#            Row_id  Hotel_id   Date_id        LT     BKG_0  Revenue_0  \
# count  152882.00 152882.00 152882.00 152882.00 152882.00  152882.00
# mean  2681202.03      2.60  43380.16    184.10      7.62     630.55
# std   1155918.67      1.11    145.27    104.67     18.93    1659.25
# min   1000001.00      1.00  43060.00      0.00      0.00       0.00
# 25%   2038221.25      2.00  43274.00     94.00      0.00       0.00
# 50%   3076441.50      3.00  43379.00    185.00      0.00       0.00
# 75%   4114661.75      4.00  43485.00    275.00      6.00     520.82
# max   4152882.00      4.00  43736.00    365.00    244.00   27764.93
#
#        PriceComp1_0  PriceComp2_0  PriceComp3_0  PriceComp4_0      ...        \
# count     152882.00     152882.00     152882.00     152882.00      ...
# mean          85.86        121.74        112.23        107.35      ...
# std           61.42         65.30         68.31         81.95      ...
# min            0.00          0.00          0.00          0.00      ...
# 25%           53.99         99.00         59.99         72.00      ...
# 50%           62.99        109.99         89.99         94.00      ...
# 75%          119.99        149.00        182.00        154.00      ...
# max          494.00        309.00        357.00        999.00      ...
#
#        PriceComp2_21  PriceComp3_21  PriceComp4_21    BKG_28  Revenue_28  \
# count      152882.00      152882.00      152882.00 152882.00   152882.00
# mean          107.76         100.47          96.92      4.56      393.70
# std            72.87          73.80          83.58     11.93     1132.79
# min            -1.00          -1.00          -1.00     -1.00       -1.00
# 25%            85.00          59.99           0.00      0.00        0.00
# 50%           105.00          84.99          94.00      0.00        0.00
# 75%           139.99         177.00         154.00      3.00      279.98
# max           299.00         347.00         999.00    187.00    27787.92
#
#        HotelPrice_28  PriceComp1_28  PriceComp2_28  PriceComp3_28  \
# count      152882.00      152882.00      152882.00      152882.00
# mean           85.54          72.70         103.09          96.66
# std            79.04          64.23          74.54          75.13
# min            -1.00          -1.00          -1.00          -1.00
# 25%             0.00           0.00           0.00           0.00
# 50%            75.00          59.99         104.99          82.00
# 75%           135.00         109.00         139.99         177.00
# max           319.99         439.00         299.00         327.00
#
#        PriceComp4_28
# count      152882.00
# mean           93.21
# std            84.14
# min            -1.00
# 25%             0.00
# 50%            89.99
# 75%           151.20
# max           999.00
#
# [8 rows x 35 columns]
#  Row_id           0
# Hotel_id         0
# Date_id          0
# Date             0
# LT               0
# BKG_0            0
# Revenue_0        0
# PriceComp1_0     0
# PriceComp2_0     0
# PriceComp3_0     0
# PriceComp4_0     0
# BKG_1            0
# Revenue_1        0
# BKG_7            0
# Revenue_7        0
# BKG_14           0
# Revenue_14       0
# HotelPrice_14    0
# PriceComp1_14    0
# PriceComp2_14    0
# PriceComp3_14    0
# PriceComp4_14    0
# BKG_21           0
# Revenue_21       0
# HotelPrice_21    0
# PriceComp1_21    0
# PriceComp2_21    0
# PriceComp3_21    0
# PriceComp4_21    0
# BKG_28           0
# Revenue_28       0
# HotelPrice_28    0
# PriceComp1_28    0
# PriceComp2_28    0
# PriceComp3_28    0
# PriceComp4_28    0
# dtype: int64
#
# ******* submission ********
#  shape:  (152883, 2)
#  Index(['Row_id', 'HotelPrice_0'], dtype='object')
#            Row_id  HotelPrice_0
# count  152883.00     152883.00
# mean  2681184.50          0.00
# std   1155935.23          0.00
# min         0.00          0.00
# 25%   2038220.50          0.00
# 50%   3076441.00          0.00
# 75%   4114661.50          0.00
# max   4152882.00          0.00
#  Row_id          0
# HotelPrice_0    0
# dtype: int64

# %%
print( train.columns )
print( test.columns )
# Out:
# Index(['Row_id', 'Hotel_id', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
#        'HotelPrice_0', 'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0',
#        'PriceComp4_0', 'BKG_1', 'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14',
#        'Revenue_14', 'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14',
#        'PriceComp3_14', 'PriceComp4_14', 'BKG_21', 'Revenue_21',
#        'HotelPrice_21', 'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21',
#        'PriceComp4_21', 'BKG_28', 'Revenue_28', 'HotelPrice_28',
#        'PriceComp1_28', 'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'],
#       dtype='object')
# Index(['Row_id', 'Hotel_id', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
#        'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0', 'PriceComp4_0', 'BKG_1',
#        'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
#        'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
#        'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
#        'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
#        'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
#        'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'],
#       dtype='object')

# %%
train.shape
# Out:
# (356720, 37)

# %%
train = train[ (train['BKG_1'] >= 0 ) | (train['Revenue_1'] >= 0 ) | (train['BKG_7'] >= 0) | (train['Revenue_7'] >= 0) |  \
     (train['BKG_14'] >= 0) | (train['Revenue_14'] >= 0) | (train['HotelPrice_14'] >= 0) | (train['PriceComp1_14'] >= 0 ) | \
     (train['PriceComp2_14']>=0) | (train['PriceComp3_14'] >= 0) | (train['PriceComp4_14'] >= 0) | (train['BKG_21'] >= 0) |\
     (train['Revenue_21']>=0) | (train['HotelPrice_21']>=0 ) | (train['PriceComp1_21']>=0) | (train['PriceComp2_21']>=0) | \
     (train['PriceComp3_21']>=0) | (train['PriceComp4_21']>=0) | (train['BKG_28']>=0) | (train['Revenue_28']>=0) |  (train['HotelPrice_28']>=0) | (train['PriceComp1_28']>=0) | (train['PriceComp2_28']>=0) | (train['PriceComp3_28']>=0) | (train['PriceComp4_28']>=0) ]

# %%
y_train = train['HotelPrice_0']
y_train
# Out:
# 0        209.12
# 1        189.50
# 2        165.19
# 3        170.13
# 4        184.63
# 5        158.10
# 6          0.00
# 7        243.88
# 8        193.68
# 9          0.00
# 10       164.71
# 11       172.16
# 12       119.13
# 13         0.00
# 14       244.57
# 15       158.15
# 16       248.03
# 17       188.07
# 18       174.52
# 19       177.60
# 20       169.48
# 21       158.77
# 22       171.82
# 23       161.36
# 24       153.33
# 25       158.29
# 26       158.38
# 27       125.56
# 28       178.62
# 29       152.03
#           ...
# 356690    85.00
# 356691    82.00
# 356692    85.00
# 356693    80.00
# 356694    70.00
# 356695    80.00
# 356696    65.00
# 356697    75.00
# 356698    70.00
# 356699    85.00
# 356700    61.00
# 356701    90.00
# 356702    90.00
# 356703    85.00
# 356704    80.00
# 356705    80.00
# 356706    90.00
# 356707    90.00
# 356708    90.00
# 356709    75.00
# 356710    80.00
# 356711    80.00
# 356712    80.00
# 356713    70.00
# 356714    70.00
# 356715    80.00
# 356716    85.00
# 356717    80.00
# 356718    85.00
# 356719    66.00
# Name: HotelPrice_0, Length: 355023, dtype: float64

# %%
train = train.drop('HotelPrice_0', axis=1)

# %%
ntrain = train.shape[0]
ntest = test.shape[0]

# %%
train.shape
# Out:
# (355023, 36)

# %%
train[['BKG_28', 'Revenue_28', 'HotelPrice_28',
       'PriceComp1_28', 'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28']].describe()
# Out:
#          BKG_28  Revenue_28  HotelPrice_28  PriceComp1_28  PriceComp2_28  \
# count 355023.00   355023.00      355023.00      355023.00      355023.00
# mean       4.60      397.85          86.02          73.19         103.74
# std       12.02     1149.05          78.71          64.02          74.26
# min       -1.00       -1.00          -1.00          -1.00          -1.00
# 25%        0.00        0.00           0.00           0.00          20.15
# 50%        0.00        0.00          75.00          59.99         104.99
# 75%        3.00      285.67         139.87         108.58         139.99
# max      217.00    27764.93         329.99         462.43         301.97
#
#        PriceComp3_28  PriceComp4_28
# count      355023.00      355023.00
# mean           97.29          93.76
# std            74.86          84.11
# min            -1.00          -1.00
# 25%            49.99           0.00
# 50%            83.00          89.99
# 75%           177.00         151.20
# max           347.00         999.00

# %%
train['Revenue_0'].plot.box()

# %%
train.shape
# Out:
# (355023, 36)

# %%
"""
train = train[ (train['Revenue_0']<= 10000) & (train['Revenue_1']<= 10000) & (train['Revenue_7']<= 10000) \
              & (train['Revenue_14']<= 10000) & (train['Revenue_21']<= 10000) & (train['Revenue_28']<= 10000)]
train.shape
"""
# Out:
# "\ntrain = train[ (train['Revenue_0']<= 10000) & (train['Revenue_1']<= 10000) & (train['Revenue_7']<= 10000)               & (train['Revenue_14']<= 10000) & (train['Revenue_21']<= 10000) & (train['Revenue_28']<= 10000)]\ntrain.shape\n"

# %%
all_data = pd.concat((train, test)).reset_index(drop=True)
all_
# 507904          85.00          62.00         119.95          82.00
#
#         PriceComp4_28
# 0              222.80
# 1               -1.00
# 2              260.02
# 3              263.44
# 4              260.72
# 5                0.00
# 6               -1.00
# 7              250.20
# 8              225.11
# 9               -1.00
# 10             278.25
# 11              -1.00
# 12               0.00
# 13               0.00
# 14             257.37
# 15             238.82
# 16             244.01
# 17             241.59
# 18              -1.00
# 19             247.09
# 20               0.00
# 21               0.00
# 22              -1.00
# 23             266.86
# 24              -1.00
# 25             246.03
# 26             241.68
# 27             169.98
# 28             238.51
# 29             256.12
# ...               ...
# 507875           0.00
# 507876          94.00
# 507877          -1.00
# 507878          81.00
# 507879          94.00
# 507880         219.00
# 507881           0.00
# 507882          99.00
# 507883          94.00
# 507884          94.00
# 507885           0.00
# 507886          81.00
# 507887           0.00
# 507888          81.00
# 507889          84.00
# 507890          72.00
# 507891          -1.00
# 507892          94.00
# 507893          -1.00
# 507894           0.00
# 507895           0.00
# 507896           0.00
# 507897          -1.00
# 507898          94.00
# 507899          81.00
# 507900           0.00
# 507901           0.00
# 507902          94.00
# 507903          89.00
# 507904          81.00
#
# [507905 rows x 36 columns]

# %%
all_data[ntrain:ntrain+1]
# Out:
#          Row_id  Hotel_id  Date_id        Date   LT  BKG_0  Revenue_0  \
# 355023  1000001         1    43432  28/11/2018  309   0.00       0.00
#
#         PriceComp1_0  PriceComp2_0  PriceComp3_0      ...        \
# 355023        169.15        179.00        199.00      ...
#
#         PriceComp2_21  PriceComp3_21  PriceComp4_21  BKG_28  Revenue_28  \
# 355023         159.00         161.00         154.00    0.00        0.00
#
#         HotelPrice_28  PriceComp1_28  PriceComp2_28  PriceComp3_28  \
# 355023           0.00           0.00           0.00           0.00
#
#         PriceComp4_28
# 355023           0.00
#
# [1 rows x 36 columns]

# %%
all_data[['BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28', 'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28']].describe()
# Out:
#          BKG_28  Revenue_28  HotelPrice_28  PriceComp1_28  PriceComp2_28  \
# count 507905.00   507905.00      507905.00      507905.00      507905.00
# mean       4.59      396.60          85.87          73.04         103.54
# std       11.99     1144.18          78.81          64.08          74.34
# min       -1.00       -1.00          -1.00          -1.00          -1.00
# 25%        0.00        0.00           0.00           0.00          14.47
# 50%        0.00        0.00          75.00          59.99         104.99
# 75%        3.00      284.40         139.00         109.00         139.99
# max      217.00    27787.92         329.99         462.43         301.97
#
#        PriceComp3_28  PriceComp4_28
# count      507905.00      507905.00
# mean           97.10          93.60
# std            74.94          84.12
# min            -1.00          -1.00
# 25%            39.99           0.00
# 50%            83.00          89.99
# 75%           177.00         151.20
# max           347.00         999.00

# %%
capacities['Hotel_id'] = capacities['Hotel_id'].astype(np.int64)
capacities['Capacity'] = capacities['Capacity'].astype(np.int64)
capacities.dtypes
# Out:
# Hotel_id    int64
# Capacity    int64
# dtype: object

# %%
all_data = all_data.merge(capacities, how='left', on='Hotel_id')
all_data
# Out:
#          Row_id  Hotel_id  Date_id        Date   LT  BKG_0  Revenue_0  \
# 0       1000001         1    43354  11/09/2018   37   2.80     310.47
# 1       1000002         1    43319  07/08/2018  255   1.83     267.32
# 507897  4152875         4    43681  04/08/2019  361   0.00       0.00
# 507898  4152876         4    43312  31/07/2018  226   1.00      59.70
# 507899  4152877         4    43489  24/01/2019  279   0.00       0.00
# 507900  4152878         4    43582  27/04/2019  311   0.00       0.00
# 507901  4152879         4    43510  14/02/2019  212   0.00       0.00
# 507902  4152880         4    43606  21/05/2019  240   0.00       0.00
# 507903  4152881         4    43360  17/09/2018  200   0.00       0.00
# 507904  4152882         4    43569  14/04/2019  227   0.00       0.00
#
#         PriceComp1_0  PriceComp2_0  PriceComp3_0    ...     PriceComp3_21  \
# 0             175.43        254.68        169.94    ...            185.22
# 1             179.59        216.65        159.49    ...             -1.00
# 2             106.84        155.95        155.89    ...            158.10
# 3               0.00        259.40        235.57    ...            237.76
# 4             186.09        244.76        191.40    ...            181.92
# 5             105.79        177.75        161.48    ...              0.00
# 6               0.00          0.00          0.00    ...             -1.00
# 7             267.57        283.32         14.06    ...              3.78
# 8             193.54        266.24        208.32    ...            199.28
# 9               0.00          0.00          0.00    ...             -1.00
# 10            187.78        166.64        145.34    ...            137.84
# 11            201.28        207.04        161.17    ...             -1.00
# 12              0.00        168.30        158.30    ...            164.03
# 13              0.00          0.00          0.00    ...              0.00
# 14              0.00        250.57        199.68    ...            196.94
# 15            195.36        211.23        184.85    ...            161.00
# 16            185.76        265.70          0.00    ...              0.00
# 17            214.82        254.11        179.59    ...            199.64
# 18            187.63        210.31        166.04    ...             -1.00
# 19            156.22        172.16        155.30    ...            149.58
# 20            119.13        163.46        161.91    ...              0.00
# 21            222.65        232.14        180.55    ...            194.78
# 22            141.02        200.77        162.29    ...             -1.00
# 23            197.98        217.42        191.71    ...            191.23
# 24              0.00        207.53        176.66    ...             -1.00
# 25            219.23        224.57        185.87    ...            159.89
# 26            105.03        161.21        176.07    ...            163.84
# 27            179.41        212.03        179.52    ...            163.57
# 28            192.91        200.42        186.75    ...            193.87
# 29            103.50        161.46        194.94    ...            158.96
# ...              ...           ...           ...    ...               ...
# 507875         59.99         99.95         74.99    ...             74.99
# 507876         59.99        104.95         84.99    ...             84.99
# 507877          0.00          0.00          0.00    ...             -1.00
# 507878         62.00        119.95         75.00    ...             75.00
# 507879         59.99        109.95         84.99    ...             84.99
# 507880        175.00        199.95        189.99    ...            199.99
# 507881         62.00        119.95         87.00    ...              0.00
# 507882         59.99        104.95         80.00    ...             84.99
# 507883         59.99        104.95         84.99    ...             84.99
# 507884         59.99        104.95         84.99    ...             84.99
# 507885         62.00        119.95         85.00    ...              0.00
# 507886         62.00        119.95         75.00    ...             75.00
# 507887         59.99        104.95        229.99    ...              0.00
# 507888         62.00        119.95         82.00    ...             82.00
# 507889         62.00        119.95         85.00    ...             80.00
# 507890         65.00         99.95         73.00    ...             77.00
# 507891          0.00          0.00          0.00    ...             -1.00
# 507892         59.99        104.95         84.99    ...             84.99
# 507893        160.00        199.95        259.99    ...             -1.00
# 507894         59.99        109.95        229.99    ...              0.00
# 507895          0.00          0.00          0.00    ...              0.00
# 507896         59.99        104.95         84.99    ...              0.00
# 507897          0.00          0.00          0.00    ...             -1.00
BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28' ]

for col in L:
    print('\n this is column: ', col)
    s = 0
    for i in range(len(test)) :
        if all_data[col][i] <0 :
                   s+=1
    print( s )
                   
"""
# Out:
# "\nL = [ 'Row_id', 'Hotel_id', 'Date_id', 'LT', 'BKG_0', 'Revenue_0',\n       'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0', 'PriceComp4_0', 'BKG_1',\n       'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',\n       'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',\n       'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',\n       'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',\n       'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',\n       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28' ]\n\nfor col in L:\n    print('\n this is column: ', col)\n    s = 0\n    for i in range(len(test)) :\n        if all_data[col][i] <0 :\n                   s+=1\n    print( s )\n                   \n"

# %%
test[ (test['BKG_1'] < 0 ) & (test['Revenue_1'] < 0 ) & (test['BKG_7'] < 0) & (test['Revenue_7']<0) &  \
     (test['BKG_14']<0) & (test['Revenue_14']<0) & (test['HotelPrice_14']<0) & (test['PriceComp1_14'] <0 ) & \
     (test['PriceComp2_14']<0) & (test['PriceComp3_14']<0) & (test['PriceComp4_14']<0) & (test['BKG_21']<0) & \
     (test['Revenue_21']) & (test['HotelPrice_21'] ) & (test['PriceComp1_21']<0) & (test['PriceComp2_21']<0) & \
     (test['PriceComp3_21']<0) & (test['PriceComp4_21']<0) & (test['BKG_28']<0) & (test['Revenue_28']<0) &  (test['HotelPrice_28']<0) & (test['PriceComp1_28']) & (test['PriceComp2_28']<0) & (test['PriceComp3_28']<0) & (test['PriceComp4_28']<0) ].count()
# Out:
# Row_id           817
# Hotel_id         817
# Date_id          817
# Date             817
# LT               817
# BKG_0            817
# Revenue_0        817
# PriceComp1_0     817
# PriceComp2_0     817
# PriceComp3_0     817
# PriceComp4_0     817
# BKG_1            817
# Revenue_1        817
# BKG_7            817
# Revenue_7        817
# BKG_14           817
# Revenue_14       817
# HotelPrice_14    817
# PriceComp1_14    817
# PriceComp2_14    817
# PriceComp3_14    817
# PriceComp4_14    817
# BKG_21           817
# Revenue_21       817
# HotelPrice_21    817
# PriceComp1_21    817
# PriceComp2_21    817
# PriceComp3_21    817
# PriceComp4_21    817
# BKG_28           817
# Revenue_28       817
# HotelPrice_28    817
# PriceComp1_28    817
# PriceComp2_28    817
# PriceComp3_28    817
# PriceComp4_28    817
# dtype: int64

# %%
all_data['Date'] = pd.to_datetime( all_data.Date, format="%d/%m/%Y") # year in upper case

# %%
all_data['month'] = all_data['Date'].dt.month
all_data['year'] = all_data['Date'].dt.year

all_data.head()
# Out:
#     Row_id  Hotel_id  Date_id       Date   LT  BKG_0  Revenue_0  PriceComp1_0  \
# 0  1000001         1    43354 2018-09-11   37   2.80     310.47        175.43
# 1  1000002         1    43319 2018-08-07  255   1.83     267.32        179.59
# 2  1000003         1    43493 2019-01-28  298   0.00       0.00        106.84
# 3  1000004         1    43371 2018-09-28  220   2.75     498.15          0.00
# 4  1000005         1    43387 2018-10-14  136   0.93     178.42        186.09
#
#    PriceComp2_0  PriceComp3_0  ...   BKG_28  Revenue_28  HotelPrice_28  \
# 0        254.68        169.94  ...     2.71      305.81         241.82
# 1        216.65        159.49  ...    -1.00       -1.00          -1.00
# 2        155.95        155.89  ...     0.00        0.00         173.95
# 3        259.40        235.57  ...     1.93      348.41         180.54
# 4        244.76        191.40  ...     0.91      175.16         179.20
#
#    PriceComp1_28  PriceComp2_28  PriceComp3_28  PriceComp4_28  Capacity  \
# 0         188.60         259.64         186.01         222.80        23
# 1          -1.00          -1.00          -1.00          -1.00        23
# 2         102.82         205.64         161.21         260.02        23
# 3           0.00         220.56         229.74         263.44        23
# 4         180.83         248.96         188.42         260.72        23
#
#    month  year
# 0      9  2018
# 1      8  2018
# 2      1  2019
# 3      9  2018
# 4     10  2018
#
# [5 rows x 39 columns]

# %%
all_data[ all_data < 0 ].count()
# Out:
# Row_id                0
# Hotel_id              0
# Date_id               0
# Date             507905
# LT                    0
# BKG_0                 0
# Revenue_0             0
# PriceComp1_0          0
# PriceComp2_0          0
# PriceComp3_0          0
# PriceComp4_0          0
# BKG_1              1005
# Revenue_1           933
# BKG_7             17105
# Revenue_7         16602
# BKG_14            35626
# Revenue_14        34652
# HotelPrice_14     34213
# PriceComp1_14     34311
# PriceComp2_14     34227
# PriceComp3_14     34297
# PriceComp4_14     34252
# BKG_21            53857
# Revenue_21        52456
# HotelPrice_21     51835
# PriceComp1_21     51977
# PriceComp2_21     51840
# PriceComp3_21     51961
# PriceComp4_21     51888
# BKG_28            71786
# Revenue_28        70040
# HotelPrice_28     69199
# PriceComp1_28     69368
# PriceComp2_28     69208
# PriceComp3_28     69359
# PriceComp4_28     69226
# Capacity              0
# month                 0
# year                  0
# dtype: int64

# %%
all_data.columns
# Out:
# Index(['Row_id', 'Hotel_id', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
#        'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0', 'PriceComp4_0', 'BKG_1',
#        'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
#        'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
#        'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
#        'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
#        'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
#        'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28', 'Capacity', 'month',
#        'year'],
#       dtype='object')

# %%
all_data = all_data[['Row_id', 'Hotel_id', 'year', 'month', 'Date_id', 'Date', 'LT', 'BKG_0', 'Revenue_0',
       'PriceComp1_0', 'PriceComp2_0', 'PriceComp3_0', 'PriceComp4_0', 'BKG_1',
       'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
       'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
       'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
       'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
       'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28', 'Capacity']]

# %%
all_data = all_data.drop('Date', axis=1)
all_data
# Out:
#          Row_id  Hotel_id  year  month  Date_id   LT  BKG_0  Revenue_0  \
# 0       1000001         1  2018      9    43354   37   2.80     310.47
# 1       1000002         1  2018      8    43319  255   1.83     267.32
# 2       1000003         1  2019      1    43493  298   0.00       0.00
# 3       1000004         1  2018      9    43371  220   2.75     498.15
# 4       1000005         1  2018     10    43387  136   0.93     178.42
# 5       1000006         1  2019      2    43521  325   0.00       0.00
# 6       1000007         1  2018     11    43430  360   0.00       0.00
# 7       1000008         1  2018      8    43324   37  11.20    1809.55
# 8       1000009         1  2018      7    43311   94   5.48     989.52
# 9       1000010         1  2019      5    43600  348   0.00       0.00
# 10      1000011         1  2019      3    43527  193   0.00       0.00
# 11      1000012         1  2018      8    43336  258   0.97     143.85
# 12      1000013         1  2018      3    43167   55   2.87     299.40
# 13      1000014         1  2019      7    43658  332   0.00       0.00
# 14      1000015         1  2018      8    43323   93   6.42    1195.86
# 16               0.00         244.01        23
# 17             195.97         241.59        23
# 18              -1.00          -1.00        23
# 19             151.39         247.09        23
# 20               0.00           0.00        23
# 21               0.00           0.00        23
# 22              -1.00          -1.00        23
# 23             193.66         266.86        23
# 24              -1.00          -1.00        23
# 25             163.31         246.03        23
# 26             151.07         241.68        23
# 27             162.97         169.98        23
# 28             201.34         238.51        23
# 29             154.33         256.12        23
# ...               ...            ...       ...
# 507875          74.99           0.00        51
# 507876          84.99          94.00        51
# 507877          -1.00          -1.00        51
# 507878          75.00          81.00        51
# 507879          84.99          94.00        51
# 507880         199.99         219.00        51
# 507881           0.00           0.00        51
# 507882          84.99          99.00        51
# 507883          84.99          94.00        51
# 507884          84.99          94.00        51
# 507885           0.00           0.00        51
# 507886          82.00          81.00        51
# 507887           0.00           0.00        51
# 507888          82.00          81.00        51
# 507889          80.00          84.00        51
# 507890          77.00          72.00        51
# 507891          -1.00          -1.00        51
# 507892          84.99          94.00        51
# 507893          -1.00          -1.00        51
# 507894           0.00           0.00        51
# 507895           0.00           0.00        51
# 507896           0.00           0.00        51
# 507897          -1.00          -1.00        51
# 507898         189.99          94.00        51
# 507899          77.00          81.00        51
# 507900           0.00           0.00        51
# 507901          75.00           0.00        51
# 507902          87.00          94.00        51
# 507903          79.99          89.00        51
# 507904          82.00          81.00        51
#
# [507905 rows x 38 columns]

# %% [markdown]
# # group by

# %%
"""
L = ['BKG_1', 'Revenue_1' ] # contains columns having negative values

for col in L:
    
    all_data.loc[ all_data[col]<0, col] = np.nan

    gb = all_data.groupby(by=['Hotel_id', 'year', 'month'], as_index=False)[col].mean()

    for i in range(len(all_data)):
        if ( isnan( all_data[col][i]) ):
            all_data[col][i] = gb[ (gb['Hotel_id'] == all_data['Hotel_id'][i]) & ( gb['year'] == all_data['year'][i]) & ( gb['month'] == all_data['month'][i]) ][col]

"""
# Out:
# "\nL = ['BKG_1', 'Revenue_1' ] # contains columns having negative values\n\nfor col in L:\n    \n    all_data.loc[ all_data[col]<0, col] = np.nan\n\n    gb = all_data.groupby(by=['Hotel_id', 'year', 'month'], as_index=False)[col].mean()\n\n    for i in range(len(all_data)):\n        if ( isnan( all_data[col][i]) ):\n            all_data[col][i] = gb[ (gb['Hotel_id'] == all_data['Hotel_id'][i]) & ( gb['year'] == all_data['year'][i]) & ( gb['month'] == all_data['month'][i]) ][col]\n\n"

# %%
"""
L = ['BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
       'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
       'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
       'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
       'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'] # contains columns having negative values

for col in L:
    
    all_data.loc[ all_data[col]<0, col] = np.nan

    gb = all_data.groupby(by=['Hotel_id', 'year', 'month'], as_index=False)[col].mean()

    for i in range(len(all_data)):
        if ( isnan( all_data[col][i]) ):
            all_data[col][i] = gb[ (gb['Hotel_id'] == all_data['Hotel_id'][i]) & ( gb['year'] == all_data['year'][i]) & ( gb['month'] == all_data['month'][i]) ][col]

"""
# Out:
# "\nL = ['BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',\n       'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',\n       'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',\n       'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',\n       'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',\n       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'] # contains columns having negative values\n\nfor col in L:\n    \n    all_data.loc[ all_data[col]<0, col] = np.nan\n\n    gb = all_data.groupby(by=['Hotel_id', 'year', 'month'], as_index=False)[col].mean()\n\n    for i in range(len(all_data)):\n        if ( isnan( all_data[col][i]) ):\n            all_data[col][i] = gb[ (gb['Hotel_id'] == all_data['Hotel_id'][i]) & ( gb['year'] == all_data['year'][i]) & ( gb['month'] == all_data['month'][i]) ][col]\n\n"

# %%
all_data.shape
# Out:
# (507905, 38)

# %% [markdown]
# # negative values =) nan, nan=) mean

# %%
L = ['BKG_1',
       'Revenue_1', 'BKG_7', 'Revenue_7', 'BKG_14', 'Revenue_14',
       'HotelPrice_14', 'PriceComp1_14', 'PriceComp2_14', 'PriceComp3_14',
       'PriceComp4_14', 'BKG_21', 'Revenue_21', 'HotelPrice_21',
       'PriceComp1_21', 'PriceComp2_21', 'PriceComp3_21', 'PriceComp4_21',
       'BKG_28', 'Revenue_28', 'HotelPrice_28', 'PriceComp1_28',
       'PriceComp2_28', 'PriceComp3_28', 'PriceComp4_28'] # contains columns having negative values

for col in L:
    
    all_data.loc[ all_data[col]<0, col] = np.nan

# %%
all_data[ all_data < 0 ].count()
# Out:
# Row_id           0
# Hotel_id         0
# year             0
# month            0
# Date_id          0
# LT               0
# BKG_0            0
# Revenue_0        0
# PriceComp1_0     0
# PriceComp2_0     0
# PriceComp3_0     0
# PriceComp4_0     0
# BKG_1            0
# Revenue_1        0
# BKG_7            0
# Revenue_7        0
# BKG_14           0
# Revenue_14       0
# HotelPrice_14    0
# PriceComp1_14    0
# PriceComp2_14    0
# PriceComp3_14    0
# PriceComp4_14    0
# BKG_21           0
# Revenue_21       0
# HotelPrice_21    0
# PriceComp1_21    0
# PriceComp2_21    0
# PriceComp3_21    0
# PriceComp4_21    0
# BKG_28           0
# Revenue_28       0
# HotelPrice_28    0
# PriceComp1_28    0
# PriceComp2_28    0
# PriceComp3_28    0
# PriceComp4_28    0
# Capacity         0
# dtype: int64

# %%
all_data = all_data.fillna( all_data.mean() )

# %%
all_data.isnull().sum()
# Out:
# Row_id           0
# Hotel_id         0
# year             0
# month            0
# Date_id          0
# LT               0
# BKG_0            0
# Revenue_0        0
# PriceComp1_0     0
# PriceComp2_0     0
# PriceComp3_0     0
# PriceComp4_0     0
# BKG_1            0
# Revenue_1        0
# BKG_7            0
# Revenue_7        0
# BKG_14           0
# Revenue_14       0
# HotelPrice_14    0
# PriceComp1_14    0
# PriceComp2_14    0
# PriceComp3_14    0
# PriceComp4_14    0
# BKG_21           0
# Revenue_21       0
# HotelPrice_21    0
# PriceComp1_21    0
# PriceComp2_21    0
# PriceComp3_21    0
# PriceComp4_21    0
# BKG_28           0
# Revenue_28       0
# HotelPrice_28    0
# PriceComp1_28    0
# PriceComp2_28    0
# PriceComp3_28    0
# PriceComp4_28    0
# Capacity         0
# dtype: int64

# %% [markdown]
# # seperating train and test

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %%
train.shape
# Out:
# (355023, 38)

# %% [markdown]
# # random forest regression

# %%
#rf_features = ['shop_id', 'item_id', 'item_cnt', 'transactions', 'year',
 #              'item_cnt_mean', 'item_cnt_std', 'item_cnt_shifted1', 
  #             'shop_mean', 'item_mean', 'item_trend', 'mean_item_cnt']

"""

rf_features = all_data.columns


rf_train = X_train[rf_features]
rf_val = X_validation[rf_features]
rf_test = X_test[rf_features]
"""
# Out:
# '\n\nrf_features = all_data.columns\n\n\nrf_train = X_train[rf_features]\nrf_val = X_validation[rf_features]\nrf_test = X_test[rf_features]\n'

# %%
"""
rf_model = RandomForestRegressor(n_estimators=50, max_depth=7, random_state=0, n_jobs=-1)
rf_model.fit(train, y_train)
"""
# Out:
# '\nrf_model = RandomForestRegressor(n_estimators=50, max_depth=7, random_state=0, n_jobs=-1)\nrf_model.fit(train, y_train)\n'

# %%
"""
rf_train_pred = rf_model.predict(train)
rf_test_pred = rf_model.predict(test)

rmse = np.sqrt(mean_squared_error(rf_train_pred, y_train))
print('rmse of train : ' , rmse)
"""
# Out:
# "\nrf_train_pred = rf_model.predict(train)\nrf_test_pred = rf_model.predict(test)\n\nrmse = np.sqrt(mean_squared_error(rf_train_pred, y_train))\nprint('rmse of train : ' , rmse)\n"

# %% [markdown]
# # Linear regression

# %%
lr_scaler = MinMaxScaler()
lr_scaler.fit(train)
lr_train = lr_scaler.transform(train)
lr_test = lr_scaler.transform(test)

lr_model = LinearRegression(n_jobs=-1)
lr_model.fit(lr_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
lr_train_pred = lr_model.predict(train)
lr_test_pred = lr_model.predict(test)

# %%
rmse = np.sqrt(mean_squared_error(lr_train_pred, y_train))
print('rmse of train : ' , rmse)
# Out:
# rmse of train :  2556749.0124121318

# %% [markdown]
# # lightgbm

# %%
lgbm_model=LGBMRegressor(
        n_estimators=200,
        learning_rate=0.03,
        num_leaves=32,
        colsample_bytree=0.9497036,
        subsample=0.8715623,
        max_depth=8,
        reg_alpha=0.04,
        reg_lambda=0.073,
        min_split_gain=0.0222415,
        min_child_weight=40)

# %%
lgbm_model.fit(train, y_train)


lightgbm_train_pred = lgbm_model.predict(train)
lightgbm_test_pred = lgbm_model.predict(test)

rmse = np.sqrt(mean_squared_error(y_train, lightgbm_train_pred ))
print('rmse of train : ' , rmse)
# Out:
# rmse of train :  19.558455775490586

# %% [markdown]
# # xgboost

# %%
# Use only part of features on XGBoost.
#xgb_features = ['item_cnt','item_cnt_mean', 'item_cnt_std', 'item_cnt_shifted1', 
 #               'item_cnt_shifted2', 'item_cnt_shifted3', 'shop_mean', 
  #              'shop_item_mean', 'item_trend', 'mean_item_cnt']
"""


xgb_model = XGBRegressor(max_depth=8, 
                         n_estimators=500, 
                         min_child_weight=1000,  
                         colsample_bytree=0.7, 
                         subsample=0.7, 
                         eta=0.3, 
                         seed=0)
xgb_model.fit(train, 
              y_train, 
              eval_metric="rmse", 
              eval_set=[(train, y_train), (train, y_train)], 
              verbose=20, 
              early_stopping_rounds=20)

"""
# Out:
# '\n\n\nxgb_model = XGBRegressor(max_depth=8, \n                         n_estimators=500, \n                         min_child_weight=1000,  \n                         colsample_bytree=0.7, \n                         subsample=0.7, \n                         eta=0.3, \n                         seed=0)\nxgb_model.fit(train, \n              y_train, \n              eval_metric="rmse", \n              eval_set=[(train, y_train), (train, y_train)], \n              verbose=20, \n              early_stopping_rounds=20)\n\n'

# %%
"""
xgb_train_pred = xgb_model.predict(train)

xgb_test_pred = xgb_model.predict(test)

rmse = np.sqrt(mean_squared_error(xgb_train_pred, y_train))
print('rmse of train : ' , rmse)
"""
# Out:
# "\nxgb_train_pred = xgb_model.predict(train)\n\nxgb_test_pred = xgb_model.predict(test)\n\nrmse = np.sqrt(mean_squared_error(xgb_train_pred, y_train))\nprint('rmse of train : ' , rmse)\n"

# %% [markdown]
# # lasso

# %%
"""
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))


lasso.fit(train, y_train)

y_lasso_pred = lasso.predict(train)

rmse = np.sqrt(mean_squared_error(y_lasso_pred , y_train))
print(rmse)
"""
# Out:
# '\nlasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))\n\n\nlasso.fit(train, y_train)\n\ny_lasso_pred = lasso.predict(train)\n\nrmse = np.sqrt(mean_squared_error(y_lasso_pred , y_train))\nprint(rmse)\n'

# %% [markdown]
# # ENet

# %%
"""
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

ENet.fit(train, y_train)

y_ENet_pred = ENet.predict(train)

rmse = np.sqrt(mean_squared_error(y_ENet_pred , y_train))
print(rmse)
"""
# Out:
# '\nENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))\n\nENet.fit(train, y_train)\n\ny_ENet_pred = ENet.predict(train)\n\nrmse = np.sqrt(mean_squared_error(y_ENet_pred , y_train))\nprint(rmse)\n'

# %% [markdown]
# # KRR

# %%
"""
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

KRR.fit(train, y_train)

y_KRR_pred = KRR.predict(train)

rmse = np.sqrt(mean_squared_error(y_KRR_pred , y_train))
print(rmse)
"""
# Out:
# "\nKRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)\n\nKRR.fit(train, y_train)\n\ny_KRR_pred = KRR.predict(train)\n\nrmse = np.sqrt(mean_squared_error(y_KRR_pred , y_train))\nprint(rmse)\n"

# %% [markdown]
# # Gboost

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %%
"""
GBoost.fit(train, y_train)


y_GBoost_pred = GBoost.predict(train)

rmse = np.sqrt(mean_squared_error(y_GBoost_pred , y_train))
print(rmse)
"""
# Out:
# '\nGBoost.fit(train, y_train)\n\n\ny_GBoost_pred = GBoost.predict(train)\n\nrmse = np.sqrt(mean_squared_error(y_GBoost_pred , y_train))\nprint(rmse)\n'

# %% [markdown]
# # submission

# %%
prediction_df = pd.DataFrame(test['Row_id'], columns=['Row_id'])
prediction_df['HotelPrice_0'] = lightgbm_test_pred
#prediction_df['sales'] = rf_test_pred
#prediction_df['sales'] = lr_test_pred
#prediction_df['HotelPrice_0'] = xgb_test_pred
#prediction_df['sales'] = dmatrix_test_pred
#prediction_df['sales'] = y_lasso_pred
#prediction_df['sales'] = y_ENet_pred
#prediction_df['sales'] = y_KRR_pred
#prediction_df['sales'] = y_GBoost_pred
#prediction_df['sales'] = y_stacked_averaged_models_pred
#prediction_df['sales'] = lgbdataset_pred_val




prediction_df.to_csv(r'C:\Users\pc\Desktop\Data Science Folder\Infor\submission.csv', index=False)
prediction_df.head(10)
# Out:
#          Row_id  HotelPrice_0
# 355023  1000001        170.47
# 355024  1000002        172.55
# 355025  1000003        242.57
# 355026  1000004        168.81
# 355027  1000005        140.12
# 355028  1000006        247.92
# 355029  1000007        163.41
# 355030  1000008        162.05
# 355031  1000009        206.55
# 355032  1000010          1.00
