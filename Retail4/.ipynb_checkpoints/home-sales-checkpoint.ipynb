# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
#color = sns.color_palette()
#sns.set_style('darkgrid')
import warnings
#def ignore_warn(*args, **kwargs):
#    pass
#warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)


from scipy import stats
from scipy.stats import norm, skew #for some statistics




#from subprocess import check_output
#print(check_output(["ls", "../input"]).decode("utf8")) #check the files available in the directory

# %%
train = pd.read_csv(r'C:\Users\LENOVO\Desktop\final retail\train.csv')


test = pd.read_csv(r'C:\Users\LENOVO\Desktop\final retail\test.csv')
print(train.shape)
print(test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL       65.000     8450   Pave   NaN      Reg
# 1   2          20       RL       80.000     9600   Pave   NaN      Reg
# 2   3          60       RL       68.000    11250   Pave   NaN      IR1
# 3   4          70       RL       60.000     9550   Pave   NaN      IR1
# 4   5          60       RL       84.000    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH       80.000    11622   Pave   NaN      Reg
# 1  1462          20       RL       81.000    14267   Pave   NaN      IR1
# 2  1463          60       RL       74.000    13830   Pave   NaN      IR1
# 3  1464          60       RL       78.000     9978   Pave   NaN      IR1
# 4  1465         120       RL       43.000     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0      6    2010        WD         Normal
# 1        Gar2   12500      6    2010        WD         Normal
# 2         NaN       0      3    2010        WD         Normal
# 3         NaN       0      6    2010        WD         Normal
# 4         NaN       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
train.drop('SalePrice',axis=1).columns==test.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
train.shape
# Out:
# (1460, 81)

# %%
train['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
# 5       143000
# 6       307000
# 7       200000
# 8       129900
# 9       118000
# 10      129500
# 11      345000
# 12      144000
# 13      279500
# 14      157000
# 15      132000
# 16      149000
# 17       90000
# 18      159000
# 19      139000
# 20      325300
# 21      139400
# 22      230000
# 23      129900
# 24      154000
# 25      256300
# 26      134800
# 27      306000
# 28      207500
# 29       68500
#          ...
# 1430    192140
# 1431    143750
# 1432     64500
# 1433    186500
# 1434    160000
# 1435    174000
# 1436    120500
# 1437    394617
# 1438    149700
# 1439    197000
# 1440    191000
# 1441    149300
# 1442    310000
# 1443    121000
# 1444    179600
# 1445    129000
# 1446    157900
# 1447    240000
# 1448    112000
# 1449     92000
# 1450    136000
# 1451    287090
# 1452    145000
# 1453     84500
# 1454    185000
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size after dropping Id feature is : (1460, 80)
# The test data size after dropping Id feature is : (1459, 79)

# %%
#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
train["SalePrice"] = np.log1p(train["SalePrice"])

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
#tna7i index le9dim w ta3mel index jdid 
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
print(all_data)
# Out:
# all_data size is : (2919, 79)
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# 5          796       566        320   NaN             1     1Fam       TA
# 6         1694         0          0   NaN             3     1Fam       TA
# 7         1107       983          0   NaN             3     1Fam       TA
# 8         1022       752          0   NaN             2     1Fam       TA
# 9         1077         0          0   NaN             2   2fmCon       TA
# 10        1040         0          0   NaN             3     1Fam       TA
# 11        1182      1142          0   NaN             4     1Fam       TA
# 12         912         0          0   NaN             2     1Fam       TA
# 13        1494         0          0   NaN             3     1Fam       TA
# 14        1253         0          0   NaN             2     1Fam       TA
# 15         854         0          0   NaN             2     1Fam       TA
# 16        1004         0          0   NaN             2     1Fam       TA
# 17        1296         0          0   NaN             2   Duplex      NaN
# 18        1114         0          0   NaN             3     1Fam       TA
# 19        1339         0          0   NaN             3     1Fam       TA
# 20        1158      1218          0   NaN             4     1Fam       TA
# 21        1108         0          0  Grvl             3     1Fam       TA
# 22        1795         0          0   NaN             3     1Fam       TA
# 23        1060         0          0   NaN             3   TwnhsE       TA
# 24        1060         0          0   NaN             3     1Fam       TA
# 25        1600         0          0   NaN             3     1Fam       TA
# 26         900         0          0   NaN             3     1Fam       TA
# 27        1704         0          0   NaN             3     1Fam       TA
# 28        1600         0          0   NaN             2     1Fam       TA
# 29         520         0          0   NaN             1     1Fam       TA
# ...        ...       ...        ...   ...           ...      ...      ...
# 2889       641         0          0   NaN             2     1Fam       TA
# 2890       967       671          0   NaN             4     1Fam       TA
# 2891       729         0          0   NaN             2     1Fam      NaN
# 2892      1060       336          0   NaN             4   2fmCon       TA
# 2893       576       360          0   NaN             2     1Fam       Fa
# 2894      1778         0          0   NaN             2   TwnhsE       TA
# 2895      1646         0          0   NaN             2   TwnhsE       TA
# 2896      1625         0          0   NaN             3     1Fam       TA
# 2897      1664         0          0   NaN             4   Duplex       TA
# 2898      1491         0          0   NaN             3     1Fam       TA
# 2899      1210         0          0   NaN             3     1Fam       TA
# 2900      1650         0          0   NaN             2     1Fam       TA
# 2901      1403         0          0   NaN             2     1Fam       TA
# 2902      1960         0          0   NaN             3     1Fam       Gd
# 2903      1838         0          0   NaN             3     1Fam       TA
# 2904      1600         0          0   NaN             3     1Fam      NaN
# 2905      1368         0          0   NaN             2   Duplex       TA
# 2906       616       688          0   NaN             3   TwnhsE       TA
# 2907       874         0          0   NaN             3     1Fam       TA
# 2908      1652         0          0   NaN             4   Duplex       TA
# 2909       630         0          0   NaN             1    Twnhs       TA
# 2910       546       546          0   NaN             3   TwnhsE       TA
# 2911      1360         0          0   NaN             3     1Fam       TA
# 2912       546       546          0   NaN             3    Twnhs       TA
# 2913       546       546          0   NaN             3    Twnhs       TA
# 2914       546       546          0   NaN             3    Twnhs       TA
# 2915       546       546          0   NaN             3   TwnhsE       TA
# 2916      1224         0          0   NaN             4     1Fam       TA
# 2917       970         0          0   NaN             3     1Fam       TA
# 2918       996      1004          0   NaN             3     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2  ...   SaleType ScreenPorch  Street  \
# 0              No     706.000       0.000  ...         WD           0    Pave
# 1              Gd     978.000       0.000  ...         WD           0    Pave
# 2              Mn     486.000       0.000  ...         WD           0    Pave
# 3              No     216.000       0.000  ...         WD           0    Pave
# 4              Av     655.000       0.000  ...         WD           0    Pave
# 5              No     732.000       0.000  ...         WD           0    Pave
# 6              Av    1369.000       0.000  ...         WD           0    Pave
# 7              Mn     859.000      32.000  ...         WD           0    Pave
# 8              No       0.000       0.000  ...         WD           0    Pave
# 9              No     851.000       0.000  ...         WD           0    Pave
# 10             No     906.000       0.000  ...         WD           0    Pave
# 11             No     998.000       0.000  ...        New           0    Pave
# 12             No     737.000       0.000  ...         WD         176    Pave
# 13             Av       0.000       0.000  ...        New           0    Pave
# 14             No     733.000       0.000  ...         WD           0    Pave
# 15             No       0.000       0.000  ...         WD           0    Pave
# 16             No     578.000       0.000  ...         WD           0    Pave
# 17            NaN       0.000       0.000  ...         WD           0    Pave
# 18             No     646.000       0.000  ...         WD           0    Pave
# 19             No     504.000       0.000  ...        COD           0    Pave
# 20             Av       0.000       0.000  ...        New           0    Pave
# 21             No       0.000       0.000  ...         WD           0    Pave
# 22             No       0.000       0.000  ...         WD           0    Pave
# 23             No     840.000       0.000  ...         WD           0    Pave
# 24             Mn     188.000     668.000  ...         WD           0    Pave
# 25             No       0.000       0.000  ...         WD           0    Pave
# 26             Mn     234.000     486.000  ...         WD           0    Pave
# 27             No    1218.000       0.000  ...         WD           0    Pave
# 28             Gd    1277.000       0.000  ...         WD           0    Pave
# 29             No       0.000       0.000  ...         WD           0    Pave
# ...           ...         ...         ...  ...        ...         ...     ...
# 2889           No       0.000       0.000  ...         WD           0    Pave
# 2890           No       0.000       0.000  ...         WD           0    Pave
# 2891          NaN       0.000       0.000  ...         WD           0    Pave
# 2892           Mn       0.000       0.000  ...         WD           0    Pave
# 2893           No       0.000       0.000  ...         WD           0    Grvl
# 2894           Gd    1573.000       0.000  ...        New         153    Pave
# 2895           Gd    1564.000       0.000  ...         WD         155    Pave
# 2896           Gd     776.000       0.000  ...         WD           0    Pave
# 2897           Mn       0.000       0.000  ...         WD           0    Pave
# 2898           No       0.000       0.000  ...         WD           0    Pave
# 2899           Av     576.000       0.000  ...         WD           0    Pave
# 2900           Gd     909.000       0.000  ...         WD         138    Pave
# 2901           Av    1136.000     116.000  ...         WD           0    Pave
# 2902           Av    1350.000       0.000  ...        New           0    Pave
# 2903           Gd    1455.000       0.000  ...        New           0    Pave
# 2904          NaN       0.000       0.000  ...         WD           0    Pave
# 2905           Gd    1243.000       0.000  ...         WD           0    Pave
# 2906           Mn       0.000       0.000  ...         WD           0    Pave
# 2907           No     441.000       0.000  ...         WD           0    Pave
# 2908           No     149.000       0.000  ...         WD           0    Pave
# 2909           Av     522.000       0.000  ...         WD           0    Pave
# 2910           No     252.000       0.000  ...         WD           0    Pave
# 2911           Av     119.000     344.000  ...         WD           0    Pave
# 2912           No     408.000       0.000  ...         WD           0    Pave
# 2913           No       0.000       0.000  ...         WD           0    Pave
# 2914           No       0.000       0.000  ...         WD           0    Pave
# 2915           No     252.000       0.000  ...         WD           0    Pave
# 2916           No    1224.000       0.000  ...         WD           0    Pave
# 2917           Av     337.000       0.000  ...         WD           0    Pave
# 2918           Av     758.000       0.000  ...         WD           0    Pave
#
#       TotRmsAbvGrd TotalBsmtSF  Utilities WoodDeckSF YearBuilt YearRemodAdd  \
# 0                8     856.000     AllPub          0      2003         2003
# 1                6    1262.000     AllPub        298      1976         1976
# 2                6     920.000     AllPub          0      2001         2002
# 3                7     756.000     AllPub          0      1915         1970
# 4                9    1145.000     AllPub        192      2000         2000
# 5                5     796.000     AllPub         40      1993         1995
# 6                7    1686.000     AllPub        255      2004         2005
# 7                7    1107.000     AllPub        235      1973         1973
# 8                8     952.000     AllPub         90      1931         1950
# 9                5     991.000     AllPub          0      1939         1950
# 10               5    1040.000     AllPub          0      1965         1965
# 11              11    1175.000     AllPub        147      2005         2006
# 12               4     912.000     AllPub        140      1962         1962
# 13               7    1494.000     AllPub        160      2006         2007
# 14               5    1253.000     AllPub          0      1960         1960
# 15               5     832.000     AllPub         48      1929         2001
# 16               5    1004.000     AllPub          0      1970         1970
# 17               6       0.000     AllPub          0      1967         1967
# 18               6    1114.000     AllPub          0      2004         2004
# 19               6    1029.000     AllPub          0      1958         1965
# 20               9    1158.000     AllPub        240      2005         2006
# 21               6     637.000     AllPub          0      1930         1950
# 22               7    1777.000     AllPub        171      2002         2002
# 23               6    1040.000     AllPub        100      1976         1976
# 24               6    1060.000     AllPub        406      1968         2001
# 25               7    1566.000     AllPub          0      2007         2007
# 26               5     900.000     AllPub        222      1951         2000
# 27               7    1704.000     AllPub          0      2007         2008
# 28               6    1484.000     AllPub        288      1957         1997
# 29               4     520.000     AllPub         49      1927         1950
# ...            ...         ...        ...        ...       ...          ...
# 2889             4     641.000     AllPub        184      1925         1950
# 2890             6     967.000     AllPub          0      1957         1957
# 2891             5       0.000     AllPub          0      1945         1950
# 2892             8     660.000     AllPub          0      1951         1951
# 2893             6     216.000     AllPub          0      1916         1950
# 2894             5    1573.000     AllPub        123      2005         2006
# 2895             5    1594.000     AllPub        128      2004         2005
# 2896             6    1625.000     AllPub        136      1979         1979
# 2897            10    1664.000     AllPub          0      1978         1978
# 2898             7    1491.000     AllPub        120      2001         2001
# 2899             6    1128.000     AllPub          0      1975         1975
# 2900             6    1632.000     AllPub          0      1958         1958
# 2901             5    1381.000     AllPub          0      2000         2000
# 2902             8    1728.000     AllPub        172      2005         2006
# 2903             9    1838.000     AllPub        161      2005         2006
# 2904             6       0.000     AllPub          0      1951         1951
# 2905             8    1288.000     AllPub          0      1997         1997
# 2906             5     264.000     AllPub        141      1977         1977
# 2907             5     864.000     AllPub          0      1968         2003
# 2908             8    1652.000     AllPub          0      1970         1970
# 2909             3     630.000     AllPub          0      1970         1970
# 2910             5     546.000     AllPub          0      1972         1972
# 2911             8    1104.000     AllPub        160      1969         1979
# 2912             5     546.000     AllPub          0      1970         1970
# 2913             5     546.000     AllPub          0      1970         1970
# 2914             5     546.000     AllPub          0      1970         1970
# 2915             6     546.000     AllPub          0      1970         1970
# 2916             7    1224.000     AllPub        474      1960         1996
# 2917             6     912.000     AllPub         80      1992         1992
# 2918             9     996.000     AllPub        190      1993         1994
#
#      YrSold
# 0      2008
# 1      2007
# 2      2008
# 3      2006
# 4      2008
# 5      2009
# 6      2007
# 7      2009
# 8      2008
# 9      2008
# 10     2008
# 11     2006
# 12     2008
# 13     2007
# 14     2008
# 15     2007
# 16     2010
# 17     2006
# 18     2008
# 19     2009
# 20     2006
# 21     2007
# 22     2008
# 23     2007
# 24     2010
# 25     2009
# 26     2010
# 27     2010
# 28     2006
# 29     2008
# ...     ...
# 2889   2006
# 2890   2006
# 2891   2006
# 2892   2006
# 2893   2006
# 2894   2006
# 2895   2006
# 2896   2006
# 2897   2006
# 2898   2006
# 2899   2006
# 2900   2006
# 2901   2006
# 2902   2006
# 2903   2006
# 2904   2006
# 2905   2006
# 2906   2006
# 2907   2006
# 2908   2006
# 2909   2006
# 2910   2006
# 2911   2006
# 2912   2006
# 2913   2006
# 2914   2006
# 2915   2006
# 2916   2006
# 2917   2006
# 2918   2006
#
# [2919 rows x 79 columns]

# %%
#pourcentage des données nulles 
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na
# Out:
# 1stFlrSF         0.000
# 2ndFlrSF         0.000
# 3SsnPorch        0.000
# Alley           93.217
# BedroomAbvGr     0.000
# BldgType         0.000
# BsmtCond         2.809
# BsmtExposure     2.809
# BsmtFinSF1       0.034
# BsmtFinSF2       0.034
# BsmtFinType1     2.706
# BsmtFinType2     2.741
# BsmtFullBath     0.069
# BsmtHalfBath     0.069
# BsmtQual         2.775
# BsmtUnfSF        0.034
# CentralAir       0.000
# Condition1       0.000
# Condition2       0.000
# Electrical       0.034
# EnclosedPorch    0.000
# ExterCond        0.000
# ExterQual        0.000
# Exterior1st      0.034
# Exterior2nd      0.034
# Fence           80.439
# FireplaceQu     48.647
# Fireplaces       0.000
# Foundation       0.000
# FullBath         0.000
#                  ...
# LotFrontage     16.650
# LotShape         0.000
# LowQualFinSF     0.000
# MSSubClass       0.000
# MSZoning         0.137
# MasVnrArea       0.788
# MasVnrType       0.822
# MiscFeature     96.403
# MiscVal          0.000
# MoSold           0.000
# Neighborhood     0.000
# OpenPorchSF      0.000
# OverallCond      0.000
# OverallQual      0.000
# PavedDrive       0.000
# PoolArea         0.000
# PoolQC          99.657
# RoofMatl         0.000
# RoofStyle        0.000
# SaleCondition    0.000
# SaleType         0.034
# ScreenPorch      0.000
# Street           0.000
# TotRmsAbvGrd     0.000
# TotalBsmtSF      0.034
# Utilities        0.069
# WoodDeckSF       0.000
# YearBuilt        0.000
# YearRemodAdd     0.000
# YrSold           0.000
# Length: 79, dtype: float64

# %%
#na7ina les colonnes elli ma3andhomch des valeurs nulles 
#5alina les collones elli 3andom missing values 
#w 9odem kol colonne le pourcentage des valeurs nuls
#nwaliw ne5dmou bel pourcentage  5ir m nombre de lignes
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
all_data_na
# Out:
# PoolQC         99.657
# MiscFeature    96.403
# Alley          93.217
# Fence          80.439
# FireplaceQu    48.647
# LotFrontage    16.650
# GarageQual      5.447
# GarageCond      5.447
# GarageFinish    5.447
# GarageYrBlt     5.447
# GarageType      5.379
# BsmtExposure    2.809
# BsmtCond        2.809
# BsmtQual        2.775
# BsmtFinType2    2.741
# BsmtFinType1    2.706
# MasVnrType      0.822
# MasVnrArea      0.788
# MSZoning        0.137
# BsmtFullBath    0.069
# BsmtHalfBath    0.069
# Utilities       0.069
# Functional      0.069
# GarageArea      0.034
# Electrical      0.034
# BsmtUnfSF       0.034
# Exterior1st     0.034
# Exterior2nd     0.034
# TotalBsmtSF     0.034
# GarageCars      0.034
# dtype: float64

# %%
#radineha dataframe .ya5ou colonne loula comme colonne d'index
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
#              Missing Ratio
# PoolQC              99.657
# MiscFeature         96.403
# Alley               93.217
# Fence               80.439
# FireplaceQu         48.647

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %%
##Obligatoire 5ater 3ana plusieurs collones w lezemna na9ssou f nombre de colonnes 
## donc les colonnes les plus faiblement correlées avec salesPrice elli hiya y-train na7iwhom

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = train.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")
all_data["PoolQC"].isnull().sum()
# Out:
# 0

# %%
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")
all_data["MiscFeature"].isnull().sum()
# Out:
# 0

# %%
all_data["Alley"] = all_data["Alley"].fillna("None")
all_data["Alley"].isnull().sum()
# Out:
# 0

# %%
all_data["Fence"] = all_data["Fence"].fillna("None")
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")

# %%
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))
all_data["LotFrontage"].isnull().sum()
# Out:
# 0

# %%
#GarageType: Garage location
#GarageFinish: Finition intérieure du garage
#GarageQual:Qualité de garage

for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')

# %%
#GarageCars:taille de garages en capacité de voitures 
#GarageArea:taille de garage em m2
#GarageYrBlt:Year garage was built
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)
