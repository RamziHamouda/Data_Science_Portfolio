# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
type( 5* 5.)
# Out:
# float

# %%
sales = pd.read_csv(r"C:\Users\pc\Desktop\Data Science Folder\Retail1\sales data-set.csv")

stores = pd.read_csv(r"C:\Users\pc\Desktop\Data Science Folder\Retail1\sales data-set.csv")

features = pd.read_csv(r"C:\Users\pc\Desktop\Data Science Folder\Retail1\Features data set.csv")

# %%
"""
change date format from j/m/a to a-m-j
"""

features['Date'] = pd.to_datetime(features['Date'])
sales['Date'] = pd.to_datetime(sales['Date'])

# %%
print(sales[0:1].Date, '\n', sales[-1:].Date)
# Out:
# 0   2010-05-02
# Name: Date, dtype: datetime64[ns]
#  421569   2012-10-26
# Name: Date, dtype: datetime64[ns]

# %%
print(sales[0:1].Date, '\n',  sales[-1:].Date)
# Out:
# 0   2010-05-02
# Name: Date, dtype: datetime64[ns]
#  421569   2012-10-26
# Name: Date, dtype: datetime64[ns]

# %%
print("sales", '\n', sales.head() )
print( "feautures", '\n', features.head())
print( "stores", '\n', stores.head() )
# Out:
# sales
#     Store  Dept       Date  Weekly_Sales  IsHoliday
# 0      1     1 2010-05-02      24924.50      False
# 1      1     1 2010-12-02      46039.49       True
# 2      1     1 2010-02-19      41595.55      False
# 3      1     1 2010-02-26      19403.54      False
# 4      1     1 2010-05-03      21827.90      False
# feautures
#     Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-05-02        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-12-02        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-05-03        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN  211.096358         8.106      False
# ...

# %%
df=pd.merge(sales,features, on=['Store','Date', 'IsHoliday'], how='left')
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-05-02      24924.50      False        42.31
# 1           1     1 2010-12-02      46039.49       True        38.51
# 2           1     1 2010-02-19      41595.55      False        39.93
# 3           1     1 2010-02-26      19403.54      False        46.63
# 4           1     1 2010-05-03      21827.90      False        46.50
# 5           1     1 2010-12-03      21043.39      False        57.79
# 6           1     1 2010-03-19      22136.64      False        54.58
# 7           1     1 2010-03-26      26229.21      False        51.45
# 8           1     1 2010-02-04      57258.43      False        62.27
# 9           1     1 2010-09-04      42960.91      False        65.86
# 10          1     1 2010-04-16      17596.96      False        66.32
# 11          1     1 2010-04-23      16145.35      False        64.84
# 12          1     1 2010-04-30      16555.11      False        67.41
# ...

# %%
df =  pd.merge(df,stores, on=['Store'], how='left')
print( df )
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-ed149ca889f6> in <module>
# ----> 1 df =  pd.merge(df,stores, on=['Store'], how='left')
#       2 print( df )
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     566                 self.left, self.right)
#     567
# --> 568         join_index, left_indexer, right_indexer = self._get_join_info()
#     569
#     570         ldata, rdata = self.left._data, self.right._data
#
# ...

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-05-02      24924.50      False        42.31
# 1           1     1 2010-12-02      46039.49       True        38.51
# 2           1     1 2010-02-19      41595.55      False        39.93
# 3           1     1 2010-02-26      19403.54      False        46.63
# 4           1     1 2010-05-03      21827.90      False        46.50
# 5           1     1 2010-12-03      21043.39      False        57.79
# 6           1     1 2010-03-19      22136.64      False        54.58
# 7           1     1 2010-03-26      26229.21      False        51.45
# 8           1     1 2010-02-04      57258.43      False        62.27
# 9           1     1 2010-09-04      42960.91      False        65.86
# 10          1     1 2010-04-16      17596.96      False        66.32
# 11          1     1 2010-04-23      16145.35      False        64.84
# 12          1     1 2010-04-30      16555.11      False        67.41
# ...
