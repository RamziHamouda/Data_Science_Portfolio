# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import ExtraTreesRegressor, AdaBoostRegressor
from sklearn import preprocessing, svm
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

from sklearn import model_selection



from math import ceil

# %%
train = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\sales_train_v2.csv')
test = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\test.csv')
submission = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\sample_submission.csv')
items = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\items.csv')
item_cats = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\item_categories.csv')
shops = pd.read_csv(r'C:\Users\pc\Desktop\Data Science Folder\Retail2\shops.csv')

# %% [markdown]
# # transfrom date_block_num to values between 0 and 11 only

# %%
train['date_block_num'] = train['date_block_num']%12
train.tail()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935844  10.10.2015               9       25     7409       299.0
# 2935845  09.10.2015               9       25     7460       299.0
# 2935846  14.10.2015               9       25     7459       349.0
# 2935847  22.10.2015               9       25     7440       299.0
# 2935848  03.10.2015               9       25     7460       299.0
#
#          item_cnt_day
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0

# %%
print( train.duplicated().sum() )

print( train[ train.duplicated(keep=False) ] )
# Out:
# 6
#                date  date_block_num  shop_id  item_id  item_price  \
# 76961    05.01.2013               0       54    20130       149.0
# 76962    05.01.2013               0       54    20130       149.0
# 1435365  23.02.2014               1       50     3423       999.0
# 1435367  23.02.2014               1       50     3423       999.0
# 1496765  23.03.2014               2       21     3423       999.0
# 1496766  23.03.2014               2       21     3423       999.0
# 1671872  01.05.2014               4       50     3423       999.0
# 1671873  01.05.2014               4       50     3423       999.0
# 1866322  12.07.2014               6       25     3423       999.0
# 1866340  12.07.2014               6       25     3423       999.0
# 2198564  31.12.2014              11       42    21619       499.0
# 2198566  31.12.2014              11       42    21619       499.0
#
#          item_cnt_day
# 76961             1.0
# 76962             1.0
# 1435365           1.0
# ...

# %%
def drop_duplicate(data, subset):
    print('Before drop shape:', data.shape)
    before = data.shape[0]
    data.drop_duplicates(subset,keep='first', inplace=True) #subset is list where you have to put all column for duplicate check
    data.reset_index(drop=True, inplace=True)
    print('After drop shape:', data.shape)
    after = data.shape[0]
    print('Total Duplicate:', before-after)

# %%
drop_duplicate(train, train.columns)
# Out:
# Before drop shape: (2935849, 6)
# After drop shape: (2935843, 6)
# Total Duplicate: 6

# %%
train.isnull().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %% [markdown]
# # negative/ unreasanble data

# %%
train.describe()
# we notive odd values in item_price and item_cnt_day
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06
# mean     5.247719e+00  3.300171e+01  1.019723e+04  8.908535e+02  1.242641e+00
# std      3.536219e+00  1.622698e+01  6.324293e+03  1.729801e+03  2.618837e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      2.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      5.000000e+00  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      8.000000e+00  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      1.100000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
print( train[train['item_price']<0] )
print( train[ (train['date_block_num']==4) & (train['shop_id']==32) & (train['item_id']==2973)  ] )
# it is best to fill negative values with the median of rows having common caracteristics

median = train[(train['date_block_num']==4) & (train['shop_id']==32) & (train['item_id']==2973)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

train.describe()
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 484682  15.05.2013               4       32     2973        -1.0           1.0
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 484681  23.05.2013               4       32     2973      1249.0           1.0
# 484682  15.05.2013               4       32     2973        -1.0           1.0
# 484683  06.05.2013               4       32     2973      2499.0           1.0
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06
# mean     5.247719e+00  3.300171e+01  1.019723e+04  8.908541e+02  1.242641e+00
# std      3.536219e+00  1.622698e+01  6.324293e+03  1.729801e+03  2.618837e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  7.000000e-02 -2.200000e+01
# 25%      2.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# ...

# %%
train[ train['item_cnt_day']<0] = 0
train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06  2.935843e+06
# mean     5.235259e+00  3.292025e+01  1.017472e+04  8.872387e+02  1.245210e+00
# std      3.541224e+00  1.628887e+01  6.337015e+03  1.725907e+03  2.617049e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%      2.000000e+00  2.200000e+01  4.427000e+03  2.490000e+02  1.000000e+00
# 50%      5.000000e+00  3.100000e+01  9.257000e+03  3.990000e+02  1.000000e+00
# 75%      8.000000e+00  4.700000e+01  1.566600e+04  9.990000e+02  1.000000e+00
# max      1.100000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
train = train[(train.item_price > 0) & (train.item_price < 300000)]
train.describe()
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.928486e+06  2.928486e+06  2.928486e+06  2.928486e+06  2.928486e+06
# mean     5.248408e+00  3.300294e+01  1.020028e+04  8.893625e+02  1.248338e+00
# std      3.535921e+00  1.622543e+01  6.324392e+03  1.718155e+03  2.619589e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  7.000000e-02  1.000000e+00
# 25%      2.000000e+00  2.200000e+01  4.477000e+03  2.490000e+02  1.000000e+00
# 50%      5.000000e+00  3.100000e+01  9.355000e+03  3.990000e+02  1.000000e+00
# 75%      8.000000e+00  4.700000e+01  1.569100e+04  9.990000e+02  1.000000e+00
# max      1.100000e+01  5.900000e+01  2.216900e+04  5.920000e+04  2.169000e+03

# %%
train
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# 13       08.01.2013               0       25     2574      399.00
# ...

# %%
train1 = train.groupby(by=['date_block_num','shop_id', 'item_id', ], as_index=False)['item_cnt_day'].sum()

train1
# Out:
#          date_block_num  shop_id  item_id  item_cnt_day
# 0                     0        0       32           6.0
# 1                     0        0       33           3.0
# 2                     0        0       35           1.0
# 3                     0        0       43           1.0
# 4                     0        0       51           2.0
# 5                     0        0       61           1.0
# 6                     0        0       75           1.0
# 7                     0        0       88           1.0
# 8                     0        0       95           1.0
# 9                     0        0       96           1.0
# 10                    0        0       98          25.0
# 11                    0        0      111           1.0
# 12                    0        0      149           3.0
# 13                    0        0      151           1.0
# 14                    0        0      153           1.0
# 15                    0        0      198           1.0
# ...

# %% [markdown]
# # rename a column name

# %%
train1=train1.rename(columns = {'item_cnt_day':'item_cnt_month'})

train1
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month
# 0                     0        0       32             6.0
# 1                     0        0       33             3.0
# 2                     0        0       35             1.0
# 3                     0        0       43             1.0
# 4                     0        0       51             2.0
# 5                     0        0       61             1.0
# 6                     0        0       75             1.0
# 7                     0        0       88             1.0
# 8                     0        0       95             1.0
# 9                     0        0       96             1.0
# 10                    0        0       98            25.0
# 11                    0        0      111             1.0
# 12                    0        0      149             3.0
# 13                    0        0      151             1.0
# 14                    0        0      153             1.0
# ...

# %% [markdown]
# # merge and use other data

# %%
shops.head(10)
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4
# 5          Вологда ТРЦ "Мармелад"        5
# 6      Воронеж (Плехановская, 13)        6
# 7          Воронеж ТРЦ "Максимир"        7
# 8    Воронеж ТРЦ Сити-Парк "Град"        8
# 9               Выездная Торговля        9

# %%
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops['city'] = LabelEncoder().fit_transform(shops['city'])
shops
# Out:
#                                           shop_name  shop_id  city
# 0                     !Якутск Орджоникидзе, 56 фран        0     0
# 1                     !Якутск ТЦ "Центральный" фран        1     0
# 2                                  Адыгея ТЦ "Мега"        2     1
# 3                    Балашиха ТРК "Октябрь-Киномир"        3     2
# 4                          Волжский ТЦ "Волга Молл"        4     3
# 5                            Вологда ТРЦ "Мармелад"        5     4
# 6                        Воронеж (Плехановская, 13)        6     5
# 7                            Воронеж ТРЦ "Максимир"        7     5
# 8                      Воронеж ТРЦ Сити-Парк "Град"        8     5
# 9                                 Выездная Торговля        9     6
# 10                       Жуковский ул. Чкалова 39м?       10     7
# 11                       Жуковский ул. Чкалова 39м²       11     7
# 12                              Интернет-магазин ЧС       12     8
# ...

# %%
train1 = pd.merge(train1, shops[['shop_id','city']], on=['shop_id'], how='left')
train1
# Out:
#          date_block_num  shop_id  item_id  item_cnt_month  city
# 0                     0        0       32             6.0     0
# 1                     0        0       33             3.0     0
# 2                     0        0       35             1.0     0
# 3                     0        0       43             1.0     0
# 4                     0        0       51             2.0     0
# 5                     0        0       61             1.0     0
# 6                     0        0       75             1.0     0
# 7                     0        0       88             1.0     0
# 8                     0        0       95             1.0     0
# 9                     0        0       96             1.0     0
# 10                    0        0       98            25.0     0
# 11                    0        0      111             1.0     0
# 12                    0        0      149             3.0     0
# 13                    0        0      151             1.0     0
# ...

# %%
l = list(item_cats.item_category_name)
l_cat = l

for ind in range(1,8):
    l_cat[ind] = 'Access'

for ind in range(10,18):
    l_cat[ind] = 'Consoles'

for ind in range(18,25):
    l_cat[ind] = 'Consoles Games'

for ind in range(26,28):
    l_cat[ind] = 'phone games'

for ind in range(28,32):
    l_cat[ind] = 'CD games'
for ind in range(32,37):
    l_cat[ind] = 'Card'

for ind in range(37,43):
    l_cat[ind] = 'Movie'

for ind in range(43,55):
    l_cat[ind] = 'Books'

for ind in range(55,61):
    l_cat[ind] = 'Music'

for ind in range(61,73):
    l_cat[ind] = 'Gifts'

for ind in range(73,79):
    l_cat[ind] = 'Soft'

item_cats['cats'] = l_cat
item_cats.head()
# Out:
#         item_category_name  item_category_id                     cats
# 0  PC - Гарнитуры/Наушники                 0  PC - Гарнитуры/Наушники
# 1         Аксессуары - PS2                 1                   Access
# 2         Аксессуары - PS3                 2                   Access
# 3         Аксессуары - PS4                 3                   Access
# 4         Аксессуары - PSP                 4                   Access

# %%
items1 = items.merge(item_cats[['item_category_id','cats']], how="left", on="item_category_id")[['item_id','cats']]
print( items.shape)
print(items1.shape)
print(items1)
# Out:
# (22170, 3)
# (22170, 2)
#        item_id            cats
# 0            0           Movie
# 1            1            Soft
# 2            2           Movie
# 3            3           Movie
# 4            4           Movie
# 5            5           Movie
# 6            6           Movie
# 7            7           Movie
# 8            8           Movie
# 9            9           Movie
# 10          10           Movie
# 11          11           Movie
# 12          12           Music
# 13          13           Movie
# 14          14           Movie
# 15          15           Movie
# 16          16           Movie
# 17          17           Movie
# 18          18           Movie
# 19          19           Movie
# 20          20           Movie
# 21          21           Movie
# 22          22           Movie
# 23          23           Movie
# 24          24           Movie
# 25          25           Movie
# 26          26           Movie
# 27          27  Consoles Games
# ...

# %%
items1['cats'] = LabelEncoder().fit_transform(items1['cats'])

# %%
train2 = train1.merge(items1, how="inner", on="item_id")

print(train1.shape)
print(train2.shape)
train2.head()
# Out:
# (1396245, 5)
# (1396245, 6)
#    date_block_num  shop_id  item_id  item_cnt_month  city  cats
# 0               0        0       32             6.0     0     7
# 1               0        1       32             7.0     0     7
# 2               0        2       32             1.0     1     7
# 3               0        3       32             3.0     2     7
# 4               0        4       32             2.0     3     7

# %%
train2['shop_id']= train2['shop_id'].astype('str')
train2['item_id']= train2['item_id'].astype('str')

# %%
train2 = train2[['date_block_num', 'shop_id', 'item_id', 'city', 'cats', 'item_cnt_month']]
train2.head()
# Out:
#    date_block_num shop_id item_id  city  cats  item_cnt_month
# 0               0       0      32     0     7             6.0
# 1               0       1      32     0     7             7.0
# 2               0       2      32     1     7             1.0
# 3               0       3      32     2     7             3.0
# 4               0       4      32     3     7             2.0

# %% [markdown]
# # limit type size

# %%
train2.dtypes
# Out:
# date_block_num      int64
# shop_id            object
# item_id            object
# city                int32
# cats                int32
# item_cnt_month    float64
# dtype: object

# %%
train2['date_block_num'] = train2['date_block_num'].astype(np.int16)
train2['city'] = train2['city'].astype(np.int16)
train2['cats'] = train2['cats'].astype(np.int16)
train2['item_cnt_month'] = train2['item_cnt_month'].astype(np.float32)

# %% [markdown]
# # prediction with linear regression

# %%
X = train2[['date_block_num', 'shop_id', 'item_id', 'city', 'cats']]
Y = train2['item_cnt_month']




X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.2)
list1 = [X_train, X_test, Y_train, Y_test]
for i in list1:
    print(i.shape)
	# Training Model

rg = LinearRegression(n_jobs=-1)
rg.fit(X_train, Y_train)
accuracy = rg.score(X_test, Y_test)
print(accuracy)

preds= rg.predict(X_test)

rmse = np.sqrt(mean_squared_error(preds, Y_test))
print(rmse)
# Out:
# (1116996, 5)
# (279249, 5)
# (1116996,)
# (279249,)
# 0.0015568055117890502
# 13.245367820186104

# %% [markdown]
# # prediction wiht extra tree regressor

# %%
etr = ExtraTreesRegressor(n_jobs = 1 )

# %%
etr.fit(X_train, Y_train)
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_decrease=0.0, min_impurity_split=None,
#           min_samples_leaf=1, min_samples_split=2,
#           min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#           oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
print( etr.score(X_test, Y_test) )
print( etr.score(X_train, Y_train) )

preds = etr.predict(X_test)

from sklearn.metrics import mean_squared_error 
rmse = np.sqrt(mean_squared_error(preds, Y_test))
print(rmse)
# Out:
# 0.5583538889606618
# 1.0
# 8.809262426860613

# %%
from xgboost import XGBRegressor

from sklearn.preprocessing import MinMaxScaler

import xgboost as xgb

param = {'max_depth':10, 
'subsample':1,
 'min_child_weight':0.5,
'eta':0.3, 
'num_round':1000, 
'seed':1,
 'silent':0,
'eval_metric':'rmse'}

boost = XGBRegressor()

boost.fit(X_train.values, Y_train.values)

preds = boost.predict(X_test.values)

rmse = np.sqrt(mean_squared_error(preds, Y_test.values))

print(rmse)
# Out:
# 11.124944

# %% [markdown]
# ## prediction with xgboost DMatrix

# %%
import xgboost as xgb
param = {'max_depth':10, 
'subsample':1,
'min_child_weight':0.5,
'eta':0.3, 
'num_round':1000, 
'seed':1,
'silent':0,
'eval_metric':'rmse'}

#choose what is X_train and Y_train
xgbtrain = xgb.DMatrix(X_train.values,Y_train.values)
bst = xgb.train(param, xgbtrain)
preds = bst.predict(xgb.DMatrix(X_test.values))

# we give mean_squared_error two arrays
rmse = np.sqrt(mean_squared_error(preds, Y_test.values))

print(rmse)
# Out:
# [20:00:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1424 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1482 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1514 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1580 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1576 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1426 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1496 extra nodes, 0 pruned nodes, max_depth=10
# [20:00:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 1478 extra nodes, 0 pruned nodes, max_depth=10
# ...

# %% [markdown]
# # Extract features (train2)

# %%
def _rename(prefix):
    cols = ['2013-01', '2013-02', '2013-03', '2013-04','2013-05','2013-06','2013-07','2013-08','2013-09','2013-10','2013-11','2013-12','2014-01','2014-02','2014-03','2014-04','2014-05','2014-06','2014-07','2014-08','2014-09','2014-10','2014-11','2014-12','2015-01','2015-02','2015-03','2015-04','2015-05','2015-06','2015-07','2015-08', '2015-09','2015-10']
    
    result = {}
    for i in range(1, len(cols) + 1, 1):
        result[cols[i-1]] = prefix + str(i)
    
    return result
